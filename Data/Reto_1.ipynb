# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print(dt.shape)
# Out:
# (536, 2)

# %%
dt = pd.read_csv('datos.csv', sep=';',encoding='utf-8')

dt.head()
# Out:
#    CODIGO_REGIONAL        REGIONAL  CODIGO_SEDE  \
# 0               19  REGIONAL CAUCA         9221
# 1               19  REGIONAL CAUCA         9221
# 2               19  REGIONAL CAUCA         9221
# 3               19  REGIONAL CAUCA         9221
# 4               19  REGIONAL CAUCA         9221
#
#                                                 SEDE    FICHA NIVEL_FORMACION  \
# 0  CENTRO DE TELEINFORMÁTICA Y PRODUCCIÓN INDUSTRIAL  2729230         TÉCNICO
# 1  CENTRO DE TELEINFORMÁTICA Y PRODUCCIÓN INDUSTRIAL  2729230         TÉCNICO
# 2  CENTRO DE TELEINFORMÁTICA Y PRODUCCIÓN INDUSTRIAL  2729230         TÉCNICO
# 3  CENTRO DE TELEINFORMÁTICA Y PRODUCCIÓN INDUSTRIAL  2729230         TÉCNICO
# 4  CENTRO DE TELEINFORMÁTICA Y PRODUCCIÓN INDUSTRIAL  2729230         TÉCNICO
#
#    CODIGO_PROGRAMA  VERSION_PROGRAMA  \
# 0           939202                 1
# 1           939202                 1
# 2           939202                 1
# 3           939202                 1
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CODIGO_REGIONAL     963 non-null    int64
#  1   REGIONAL            963 non-null    object
#  2   CODIGO_SEDE         963 non-null    int64
#  3   SEDE                963 non-null    object
#  4   FICHA               963 non-null    int64
#  5   NIVEL_FORMACION     963 non-null    object
#  6   CODIGO_PROGRAMA     963 non-null    int64
#  7   VERSION_PROGRAMA    963 non-null    int64
#  8   PROGRAMA            963 non-null    object
#  9   FECHA_INICIO        963 non-null    object
#  10  FECHA_FIN           963 non-null    object
#  11  JORNADA             963 non-null    object
#  12  TIPO_DOCUMENTO      963 non-null    object
#  13  NUMERO_DOCUMENTO    963 non-null    int64
#  14  NUMERO_CERTIFICADO  0 non-null      float64
# ...

# %%
columnasIrrelevantes= ['CODIGO_REGIONAL','REGIONAL','CODIGO_SEDE','SEDE','FICHA','NIVEL_FORMACION','CODIGO_PROGRAMA','VERSION_PROGRAMA','PROGRAMA','FECHA_INICIO','FECHA_FIN','JORNADA','TIPO_DOCUMENTO','NUMERO_DOCUMENTO','NUMERO_CERTIFICADO','FECHA_CERTIFICADO','NUMERO_RUTA','RUTA','ESTADO_FICHA','FECHA_REGISTRO','ESTADO_APRENDIZ']
dt.drop(columnasIrrelevantes, axis = 1, inplace=True)

dt.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
#       1 columnasIrrelevantes= ['CODIGO_REGIONAL','REGIONAL','CODIGO_SEDE','SEDE','FICHA','NIVEL_FORMACION','CODIGO_PROGRAMA','VERSION_PROGRAMA','PROGRAMA','FECHA_INICIO','FECHA_FIN','JORNADA','TIPO_DOCUMENTO','NUMERO_DOCUMENTO','NUMERO_CERTIFICADO','FECHA_CERTIFICADO','NUMERO_RUTA','RUTA','ESTADO_FICHA','FECHA_REGISTRO','ESTADO_APRENDIZ']
# ----> 2 dt.drop(columnasIrrelevantes, axis = 1, inplace=True)
#       4 dt.info()
#
# File ~\.conda\envs\BootcampIA\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
# ...

# %%
dt.head(20)
# Out:
# Empty DataFrame
# Columns: [NOVEDAD, MOTIVO_NOVEDAD]
# Index: []

# %%
dt.drop(columns='Unnamed: 23', inplace=True)
dt.info()
dt.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 963 entries, 0 to 962
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CODIGO_REGIONAL     963 non-null    int64
#  1   REGIONAL            963 non-null    object
#  2   CODIGO_SEDE         963 non-null    int64
#  3   SEDE                963 non-null    object
#  4   FICHA               963 non-null    int64
#  5   NIVEL_FORMACION     963 non-null    object
#  6   CODIGO_PROGRAMA     963 non-null    int64
#  7   VERSION_PROGRAMA    963 non-null    int64
#  8   PROGRAMA            963 non-null    object
#  9   FECHA_INICIO        963 non-null    object
#  10  FECHA_FIN           963 non-null    object
#  11  JORNADA             963 non-null    object
#  12  TIPO_DOCUMENTO      963 non-null    object
#  13  NUMERO_DOCUMENTO    963 non-null    int64
#  14  NUMERO_CERTIFICADO  0 non-null      float64
# ...

# %%
dt.dropna(inplace=True)
dt.drop_duplicates(inplace=True)
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CODIGO_REGIONAL     0 non-null      int64
#  1   REGIONAL            0 non-null      object
#  2   CODIGO_SEDE         0 non-null      int64
#  3   SEDE                0 non-null      object
#  4   FICHA               0 non-null      int64
#  5   NIVEL_FORMACION     0 non-null      object
#  6   CODIGO_PROGRAMA     0 non-null      int64
#  7   VERSION_PROGRAMA    0 non-null      int64
#  8   PROGRAMA            0 non-null      object
#  9   FECHA_INICIO        0 non-null      object
#  10  FECHA_FIN           0 non-null      object
#  11  JORNADA             0 non-null      object
#  12  TIPO_DOCUMENTO      0 non-null      object
#  13  NUMERO_DOCUMENTO    0 non-null      int64
#  14  NUMERO_CERTIFICADO  0 non-null      float64
#  15  FECHA_CERTIFICADO   0 non-null      float64
# ...

# %%
dt.head(20)
# Out:
#                                          NOVEDAD  \
# 0               Novedad integración con la media
# 1                              Retiro voluntario
# 3   Error por parte del responsable del registro
# 4               Novedad integración con la media
# 7               Novedad integración con la media
# 10                             Retiro voluntario
# 11                             Retiro voluntario
# 12              Novedad integración con la media
# 14                             Retiro voluntario
# 19              Novedad integración con la media
# 29                             Retiro voluntario
# 30                            Motivos personales
# 32                             Retiro voluntario
# 33                           Calamidad domestica
# 35                             Retiro voluntario
# 36                             Retiro voluntario
# 37                             Retiro voluntario
# 40                             Retiro voluntario
# ...

# %%
print(dt.shape)
dt.info()
# Out:
# (536, 2)
# <class 'pandas.core.frame.DataFrame'>
# Index: 536 entries, 0 to 962
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NOVEDAD         536 non-null    object
#  1   MOTIVO_NOVEDAD  536 non-null    object
# dtypes: object(2)
# memory usage: 12.6+ KB

# %%
columnas = ['NOVEDAD','MOTIVO_NOVEDAD']
for col in columnas:
    print(dt[col].value_counts())
    print('-'*20)
# Out:
# NOVEDAD
# Retiro voluntario                                  413
# Motivos personales                                  30
# Novedad integración con la media                    15
# Enfermedad                                          14
# Problemas laborales                                 10
# Problemas económicos                                 8
# Concertación Plan de mejoramiento                    8
# Cambio de domicilio                                  7
# Formación no realizada                               6
# No inició proceso de formación                       6
# Licencia de maternidad                               3
# Problemas familiares                                 3
# Error por parte del responsable del registro         2
# Calamidad domestica                                  2
# Cumple con lo solicitado en el condicionamiento      2
# Motivos laborales                                    2
# A una ficha diferente                                2
# ...

# %%
dt.drop(columns=['NOVEDAD'], inplace=True)

# %%
dt.info()
print(dt.shape)
dt.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536 entries, 0 to 962
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MOTIVO_NOVEDAD  536 non-null    object
# dtypes: object(1)
# memory usage: 8.4+ KB
# (536, 1)
#                                       MOTIVO_NOVEDAD
# 0   Según resolución #19-01063 del 22 de noviembr...
# 1                    Cambio de institución educativa
# 3  Por error se acepto y era rechazar la solicitu...
# 4  Según la solicitud No. 7-2022-19, se realiza r...
# 7  Según resolución #19-00913 del 9 de octubre de...

# %%
for col in dt.columns:
    if col in columna:
        dt[col]=dt[col].str.lower()

# %%
columnas = ['MOTIVO_NOVEDAD']
for col in columnas:
    print(dt[col].value_counts())
    print('-'*20)
# Out:
# MOTIVO_NOVEDAD
# calamidad domestica                                                                                                                                                                                                                                                                                          3
# motivos personales                                                                                                                                                                                                                                                                                           2
# calamidad domestica                                                                                                                                                                                                                                                                                          2
# ...

# %%
print(dt.shape)
# Out:
# (536, 1)

# %%
dt.to_csv('datosLimpiez.csv', index=False,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 dt.to_csv('datosLimpiez.csv', index=False, econding='utf-8')
#
# File ~\.conda\envs\BootcampIA\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_csv() got an unexpected keyword argument 'econding'

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dt.to_csv('datosLimpiezaa.csv', mode='w',encoding='utf-8',index=False)

# %%
dt.head()
# Out:
#                                       MOTIVO_NOVEDAD
# 0   según resolución #19-01063 del 22 de noviembr...
# 1                    cambio de institución educativa
# 3  por error se acepto y era rechazar la solicitu...
# 4  según la solicitud no. 7-2022-19, se realiza r...
# 7  según resolución #19-00913 del 9 de octubre de...
